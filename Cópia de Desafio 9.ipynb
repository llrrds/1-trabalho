# %% [markdown]
# ### Desafio 9
#
# Escreva uma função que retorne a soma dos múltiplos de 3 e 5 entre 0 e um número limite (parâmetro). Por exemplo, se o limite for 20, ele retornará a soma de 3, 5, 6, 9, 10, 12, 15, 18, 20.

# %%
soma = 0
for c in range (0, 100):
    if c % 5 == 0 and c % 3 == 0:
       soma += c
       print('A soma dos numeros é {}'.format(soma))
# Out:
# A soma dos numeros é 0
# A soma dos numeros é 15
# A soma dos numeros é 45
# A soma dos numeros é 90
# A soma dos numeros é 150
# A soma dos numeros é 225
# A soma dos numeros é 315
